# %% [markdown]
# - ASSIGNMENT: final-effective-particle
# - POINTS: 3
# - CATEGORY: final
# - RUBRIC: default
# - DUEDATE: 2017-05-10 08:30:00
# - GRADER: John

# %% [markdown]
# ![img](//s3.amazonaws.com/lowres.cartoonstock.com/medical-subtle-subtlety-sledge_hammers-sledgehammers-chemist-rnin572_low.jpg)
#
# <b>This is an exam. You have to work alone on this problem. You are free to consult the book, your notes, the lecture notes, your homeworks and the posted solutions.</b>
#
# The rate of a first order reaction  in spherical catalyst pellets that are 6 mm in diameter was found to be 0.001 mol/cm<sup>3</sup>/s at a pressure of 1 atm of pure reactant and 100 °C. The effective diffusivity of the reactant in the particles is known to be 0.1 cm<sup>2</sup>/s.
#
# Your colleague is concerned the small pellets will cause an excessive pressure drop and suggests that larger pellets would be better. Another colleague thinks larger particles would be worse because a preliminary experiment with larger pellets showed a lower reaction rate, which suggested that the rate might be mass transfer limited.
#
# Estimate the effectiveness factor for the 6 mm particles and use that to determine if the observed rate is limited by diffusion.
