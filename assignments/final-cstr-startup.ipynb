# %% [markdown]
# - ASSIGNMENT: final-cstr-startup
# - POINTS: 3
# - CATEGORY: final
# - RUBRIC: default
# - DUEDATE: 2017-05-10 08:30
# - GRADER: John

# %% [markdown]
# ![img](//imagecache5d.allposters.com/watermarker/93-9356-TJ78500Z.jpg)
#
# <b>This is an exam. You have to work alone on this problem. You are free to consult the book, your notes, the lecture notes, your homeworks and the posted solutions.</b>
#
# A reactant at 3×10<sup>-4</sup> mol/L is pumped at a rate of 2 L/min into a 10L CSTR filled with pure solvent.  A first order reaction occurs in the reactor. The rate constant is not known, but it is known that after a long time a steady state conversion of 60% is observed. How long did it take to reach 99% of the steady state conversion?
